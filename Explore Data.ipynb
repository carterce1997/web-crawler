# %%
import json

# %%
with open('keywords.json') as file:
    data = json.load(file)

# %%
all_keywords = []
for url, words in data.items():
    for word in words:
        if word not in all_keywords:
            all_keywords.append(word)

# %%
all_keywords
# Out:
# ['national historical gis',
#  'the national historical geographic information system',
#  'nhgis',
#  'easy access',
#  'summary tables',
#  'time series',
#  'population',
#  'housing',
#  'agriculture',
#  'economic data',
#  'gis-compatible boundary files',
#  'years',
#  'the present',
#  'all levels',
#  'u.s. census geography',
#  'states',
#  'counties',
#  'tracts',
#  'blocks',
#  'data',
#  'ipums',
#  'census',
#  'survey data',
#  'the world',
#  'time',
#  'space',
#  'ipums integration',
#  'documentation',
#  'it',
#  'change',
#  'comparative research',
#  'information',
#  'data types',
#  'analyze',
#  'individuals',
#  'family',
#  'community',
#  'context',
#  'services',
#  'charge',
#  'copyright © ipums',
#  'university',
#  'minnesota',
#  'our faq',
#  'our frequently asked questions',
#  'video tutorials',
#  'usage guides',
#  'a look',
#  'our user guide',
#  'user guide',
#  'specific questions',
#  'the data',
#  'website',
#  'an answer',
#  'our user forum',
#  'you',
#  'a question',
#  'our staff members',
#  'a fellow user',
#  'user forum',
#  'difficulties',
#  'the nhgis website',
#  'the user support team',
#  'assistance',
#  'your email',
#  'we',
#  'the problem',
#  'assistance requests',
#  'nhgis@umn.edu',
#  'suggestions',
#  'observations',
#  'praise',
#  'criticism',
#  'any nhgis features',
#  'a significant error',
#  'a complimentary ipums',
#  'nhgis mug',
#  'feedback',
#  'questions',
#  'acceptable use',
#  'nhgis data',
#  'nhgis sources',
#  'methods',
#  'features',
#  'plans',
#  'your questions',
#  'new data',
#  'revisions',
#  'improvements',
#  'existing data',
#  'the website',
#  'itself',
#  'the release log',
#  'these changes',
#  'us',
#  'twitter',
#  'prompt updates',
#  'the latest nhgis data releases',
#  '@nhgis',
#  'ipums nhgis\ninstitute',
#  'social research',
#  'data innovation\nuniversity',
#  '225 19th ave s\nminneapolis',
#  'mn',
#  'phone',
#  '612-624-5818\nfax',
#  'the ipums',
#  'national historical geographic information system',
#  'free online access',
#  'summary statistics',
#  'gis files',
#  'u.s. censuses',
#  'other nationwide surveys',
#  'the nhgis data finder',
#  'users',
#  'tools',
#  'data analysis',
#  'mapping',
#  'data files',
#  'use',
#  'spreadsheet applications',
#  'most nhgis data files',
#  'all areas',
#  'the united states',
#  'census blocks',
#  'block groups',
#  'individual states',
#  'several ipums data integration projects',
#  'the minnesota population center',
#  'the institute',
#  'innovation',
#  'the university',
#  'the nhgis project',
#  'grants',
#  'the national science foundation',
#  'the eunice kennedy shriver national institute',
#  'child health',
#  'human development',
#  'nhgis geographic crosswalks',
#  'u.s. census geographic units',
#  'one census year',
#  'units',
#  'another year',
#  'the crosswalks',
#  'high-quality tabulations',
#  "one year's census data",
#  "another year's geographic units",
#  'e.g., 1990 foreign-born population',
#  '2010 census tracts',
#  'nhgis crosswalks',
#  "the u.s. census bureau's relationship files",
#  'interpolation weights',
#  'advanced models',
#  'each interpolation weight',
#  'the proportion',
#  "a source zone's characteristics",
#  'a specific target zone',
#  'these same weights',
#  'geographically standardized time series tables',
#  'block',
#  'a preliminary version',
#  'only area-based weights',
#  'improved weights',
#  '2020 block densities',
#  'the summary data',
#  '2020 blocks',
#  'summary data',
#  "one census's geographic units",
#  'the lowest possible level',
#  "'s",
#  '"harmonized tract data',
#  'multiple years',
#  'census tract data',
#  'spatially consistent tracts',
#  '2010 tract data',
#  'a tract crosswalk',
#  'the 1990',
#  '2000 tract data',
#  '2010 tracts',
#  'lots',
#  'those smaller units',
#  'the smaller units',
#  'example',
#  'thousands',
#  'cases',
#  'multiple 2010 tracts',
#  'fast-growing areas',
#  'the outskirts',
#  'cities',
#  'figure',
#  '1990 data',
#  'the 2010 tracts',
#  'these cases',
#  'tract counts',
#  'counts',
#  'the larger 1990 tracts',
#  'their component parts',
#  'substantial errors',
#  'disaggregation models',
#  'population characteristics',
#  'source zones',
#  'inaccurately uniform distributions',
#  'the target zones',
#  'the tract-based estimates',
#  'the 1990 black population distribution',
#  'this area',
#  '1990 rates',
#  'black residents',
#  'different source levels',
#  'the southwest outskirts',
#  'charlotte',
#  'larger version',
#  'source',
#  'tract-based estimates',
#  'longitudinal tract database',
#  'ltdb',
#  'this case',
#  'no need',
#  'tract data',
#  'the census bureau',
#  'many summary tables',
#  'lower levels',
#  '"block group parts',
#  '(intersections',
#  'places',
#  'county subdivisions',
#  'some other levels',
#  'these levels',
#  'less disaggregation',
#  'many cases',
#  'only aggregation',
#  'exact\xa0counts',
#  'the allocations',
#  'the lower levels',
#  "this area's population",
#  'fact',
#  'high rates',
#  'black population',
#  'the eastern 2010 tracts',
#  'low rates',
#  'the western 2010 tracts',
#  'the options',
#  'source levels',
#  'data source',
#  'the decennial census',
#  'two questionnaires',
#  'a short-form questionnaire',
#  'a small set',
#  'all households',
#  'a long-form questionnaire',
#  'a sample',
#  'households',
#  'optimal accuracy',
#  'crosswalks',
#  'short-form data',
#  'block group parts',
#  'long-form data',
#  'some census summary tables',
#  'e.g., detailed place',
#  'birth',
#  'some other data sources',
#  'higher levels',
#  'these settings',
#  'some other source levels',
#  'the future',
#  'top',
#  'each record',
#  'a possible intersection',
#  'a single source block',
#  'a single target block',
#  'an interpolation weight',
#  'approximately what portion',
#  "the source zone's population",
#  'housing units',
#  'the intersection',
#  'these weights',
#  'any characteristics',
#  'source blocks',
#  'e.g., females',
#  'target blocks',
#  'count data',
#  '1990 blocks',
#  '2010 blocks',
#  'all census geographic units',
#  'a set',
#  'the same census year',
#  'any 2010 census units',
#  '2000 counts',
#  '2010 school districts',
#  'the steps',
#  'bgps',
#  'one key difference',
#  'an extra step',
#  'nhgis terminology',
#  'a type',
#  'compound level',
#  'them',
#  'a selection window',
#  'geographic levels',
#  'the "show compound geographic levels" option',
#  'the upper right',
#  'bgp levels',
#  'the "block group',
#  'summary files',
#  'different versions',
#  'different sets',
#  'geographic units',
#  'block crosswalks',
#  'their inclusion',
#  'multiple interpolation weights',
#  'different census counts',
#  'the technical details section',
#  'the bgp crosswalks',
#  'the proportions',
#  'block-level characteristics',
#  'both the source bgp',
#  'the target zone',
#  'the separate interpolation weights',
#  'different block-level characteristics',
#  'crosswalk users',
#  'the weights',
#  'their data',
#  'interest',
#  'a user',
#  'employed females',
#  'weights',
#  'total populations',
#  'the distribution',
#  "the general population's distribution",
#  'high-income households',
#  'total households',
#  'most cases',
#  '2010 counties',
#  'census tracts',
#  'results',
#  'tables',
#  'the 2011-2019 releases',
#  'american community survey',
#  '(acs',
#  'no changes',
#  'its definitions',
#  'censuses',
#  'changes',
#  'county boundaries',
#  'recent decades',
#  'a few exceptions',
#  'our crosswalks',
#  'these discrepancies',
#  'facilitate allocations',
#  'the census units',
#  'any year',
#  'the u.s',
#  'basics',
#  'the links',
#  'comma-separated values',
#  'zip archives',
#  'each zip file',
#  'a "readme" text file',
#  'the content',
#  'the crosswalk file',
#  'detail',
#  'methodology',
#  'the interpolation',
#  'target-density weighting',
#  '(tdw',
#  '(schroeder',
#  'tdw',
#  'characteristics',
#  'each source zone',
#  'a distribution',
#  'the densities',
#  'another characteristic',
#  'target zones',
#  'two 2010 blocks',
#  'the same 10:1 ratio',
#  'the 2020 block',
#  '2000 blocks',
#  'some more advanced modeling',
#  'these pages',
#  'block-level data',
#  "each bgp's characteristics",
#  'each target zone',
#  'the python-based source code',
#  'these calculations',
#  'this github repository',
#  'an faq',
#  'additional documentation',
#  'geographic coverage',
#  'each crosswalk file',
#  'the entire u.s',
#  '.',
#  'an entire state',
#  'state-level files',
#  'all target zones',
#  'the state',
#  'any source zones',
#  'those target zones',
#  'some source zones',
#  'neighboring states',
#  'state boundary lines',
#  'a complete set',
#  'a single state',
#  'source data',
#  'both the state',
#  'its neighboring states',
#  'they',
#  'the required input data',
#  'the block crosswalks',
#  'the nationwide bgp crosswalks',
#  'many millions',
#  'records',
#  'some applications',
#  'geographic identifiers',
#  'two types',
#  'block crosswalk files',
#  'the codes',
#  'gisjoin identifiers',
#  'the source',
#  'identifiers',
#  'details',
#  'those identifiers',
#  'the readme file',
#  'a single interpolation weight',
#  '(labeled "weight',
#  'the expected proportion',
#  "the source block's population",
#  'each target block',
#  'four distinct weights',
#  'blank values',
#  '1990 source zones',
#  'the zone identifier fields',
#  'a source',
#  'target zone',
#  'coastal or great lakes waters',
#  'nhgis boundary files',
#  'offshore areas',
#  'relationships',
#  'later census zones',
#  'block relationship files',
#  'intersections',
#  'none',
#  'the blocks',
#  'a "blank" target zone',
#  'any reported population',
#  'the records',
#  'all source',
#  'the file',
#  'the same conditions',
#  'all nhgis data',
#  'citation',
#  'ipums nhgis environmental summaries',
#  'land cover',
#  'climate data',
#  'the nhgis environmental summary data files',
#  'land cover data',
#  'the national land cover database',
#  '(nlcd',
#  'the prism climate group',
#  'this section',
#  'the geospatial processing',
#  'the county',
#  'census tract summaries',
#  'the visible features',
#  "the earth's surface",
#  'satellite imagery',
#  'aerial photography',
#  'each pixel',
#  'an image',
#  'a land cover class',
#  'e.g., water, vegetation',
#  'bare rock',
#  'wetlands',
#  'visual interpretation',
#  'more commonly, automated classification algorithms',
#  'researchers',
#  'the amount',
#  'land',
#  'a particular class(es',
#  'nhgis land cover summaries',
#  'a consortium',
#  'federal agencies',
#  'the nlcd data',
#  'a 30-meter spatial resolution',
#  'a decision-tree classification',
#  'landsat satellite imagery',
#  'environmental summaries',
#  '2011 versions',
#  'the nlcd',
#  'these three nlcd versions',
#  'a consistent methodology',
#  'sixteen land cover classes',
#  'the following process',
#  'the land cover summaries',
#  'the contiguous united states',
#  'these areas',
#  'land cover summaries',
#  'alaska',
#  'hawaii',
#  'more geographic levels',
#  'nlcd',
#  'no land cover data',
#  'puerto rico',
#  'other territories',
#  'the weather conditions',
#  'a given area',
#  'a long time period',
#  'these data',
#  'raster files',
#  'an estimate',
#  'temperature',
#  'precipitation',
#  'a given time period',
#  'nearby monitoring stations',
#  'scientists',
#  'modeling techniques',
#  'station-level data',
#  'datasets',
#  'nhgis climate summaries',
#  'oregon state university',
#  'the northwest alliance',
#  'computational science',
#  'engineering',
#  'the prism data',
#  'a 4-kilometer spatial resolution',
#  '30-year normal temporal resolutions',
#  'available climate variables',
#  'mean dew point',
#  'minimum',
#  'maximum vapor pressure deficit',
#  'pressure',
#  'prism temporal resolutions',
#  'time periods',
#  'nhgis files',
#  'the 30-year normals resolution',
#  'some users',
#  'more detail',
#  'normals',
#  'baseline datasets',
#  'the long-run average climatic conditions',
#  'an area',
#  '13 times steps',
#  'a normals',
#  'each month',
#  'a january 30-year normal maximum temperature',
#  'prism',
#  'the average',
#  'the 30 january monthly average maximum temperatures',
#  'a july 30-year normal precipitation',
#  'the 30 july monthly total precipitation measurements',
#  'an annual normal precipitation',
#  '30 yearly total precipitation measurements',
#  'prism climate variables',
#  'process nhgis',
#  'the climate summaries',
#  'areas',
#  'climate summaries',
#  '30-year normals',
#  'the contiguous u.s.. summary statistics',
#  'each climate variable',
#  'each county',
#  'the environmental summaries',
#  'the contents',
#  'the data files',
#  'three layouts',
#  'the time',
#  'row layout',
#  'the unique idenfier',
#  'each geographic unit',
#  'the gisjoin',
#  'the identifiers',
#  'nhgis data tables',
#  'boundary files',
#  'a county gisjoin',
#  'these codes',
#  'a census tract gisjoin',
#  'the nhgis environmental data summaries',
#  'nhgis citation',
#  'nhgis privacy-protected demonstration data',
#  'two versions',
#  '2010 census summary tables',
#  'a major change',
#  'its framework',
#  'privacy',
#  'the 2020 das',
#  'the privacy-protected demonstration data facilitate assessments',
#  'the new framework',
#  'a broad range',
#  'the quality',
#  'different das versions',
#  'final design decisions',
#  '2020 data',
#  'the confidentiality',
#  '2020 census respondents',
#  'the u.s. census bureau',
#  'a framework termed "differential privacy',
#  'october',
#  'a demonstration data product',
#  'the impact',
#  'differential privacy',
#  'the utility',
#  'accuracy',
#  'decennial census data',
#  'this product',
#  'a differentially private version',
#  'the 2010 decennial census',
#  'several assessments',
#  'the demonstration data',
#  'the workshop',
#  '2020 data products',
#  'the committee',
#  'national statistics',
#  'these assessments',
#  'limitations',
#  'the differentially private data',
#  'low-population geographic units',
#  'no other sources',
#  'complete, reliable population data',
#  'workshop participants',
#  'the bureau',
#  'additional demonstration data',
#  'utility',
#  'the differentially private algorithm',
#  'june',
#  'a privacy-protected microdata file',
#  'ppmf',
#  'each programming sprint',
#  'a corresponding set',
#  'quality metrics',
#  'its differentially private algorithm',
#  'each version',
#  'the ppmf',
#  'those modifications',
#  'data users',
#  'a privacy-protected summary file',
#  'ppsf',
#  'our ppsf',
#  'tabulations',
#  'each row',
#  'a geographic unit',
#  'each column',
#  'a summary statistic',
#  '(e.g., the count',
#  'females',
#  'comparisons',
#  'comparable data',
#  'the ppsf',
#  'original 2010 census summary file',
#  'these linked files',
#  'nhgis privacy-protected 2010 census demonstration data  product',
#  'input',
#  'a copy',
#  'nhgis+diffpriv@umn.edu',
#  'any comments',
#  'these files',
#  'our first set',
#  'privacy-protected 2010 census demonstration data',
#  'the original 2010 summary file',
#  "the census bureau's 2010 demonstration data products baseline",
#  'format',
#  'content',
#  'later demonstration data releases',
#  'this separate page',
#  'this version',
#  'the privacy-protected 2010 census demonstration data',
#  'the 2020-05-27 vintage',
#  'this file',
#  'a new version',
#  "the bureau's differentialy private topdown algorithm",
#  '(tda',
#  'post-processing all noisy measurements',
#  'one time',
#  'tda employs',
#  'a multipass solution',
#  'this vintage',
#  'the first pass',
#  'total population counts',
#  'relationship',
#  'group quarters',
#  'the second pass',
#  'the pl 94-171 redistricting dataset',
#  'the third pass processed counts',
#  'the population',
#  'program',
#  'the final pass',
#  'all remaining counts',
#  'the multipass version',
#  'output',
#  'each pass',
#  'the counts',
#  'prior passes',
#  'the 63 race categories',
#  'pass',
#  'the sum',
#  'the total population count',
#  'the particular circumstances',
#  'programming sprint ii',
#  'no housing unit privacy-protected microdata file',
#  'this release',
#  'hence no housing tables',
#  'housing data',
#  'subsequent releases',
#  'the first demonstration data products',
#  'the privacy loss budget',
#  'person-level counts',
#  'queries',
#  'the 2020-09-17 vintage',
#  'the production',
#  'recent changes',
#  'the operational schedule',
#  'the 2020 decennial census',
#  'a focus',
#  'redistricting data',
#  'the first release',
#  'small-area data',
#  'the v2020',
#  'the multipass post-processing topdown',
#  'algorithm',
#  'the tda',
#  'legal',
#  'political units',
#  'a new geographic hierarchy',
#  'american indian',
#  'alaska native tribal areas',
#  'the total population',
#  'all persons',
#  'federally or state-recognized tribal areas',
#  'invariant.. update - 2020/11/16',
#  'an erratum note',
#  'the 2020-09-17 vintage ppmf',
#  'the geographic level allocation',
#  'the person-level allocation',
#  'the allocation',
#  'the occupancy status query',
#  '100%',
#  'the 2020-11-16 vintage',
#  'an error',
#  'the code',
#  'the v2020-09-17 ppmf',
#  'the 2021-04-28_12-2 vintage',
#  'prior ppmf releases',
#  'the 2021-04-18_4-5 vintage',
#  'the 2021-04-28_4-5 vintage',
#  'the 2021-06-08 vintage',
#  'the disclosure avoidance parameters',
#  'the 2021-06-08 ppmf',
#  'the 2020 pl94-171 redistricting data',
#  'the overall privacy loss budget',
#  '(epsilon',
#  'this ppmf',
#  'the person tables',
#  'the housing unit table',
#  'allocation details',
#  'state-level summaries',
#  'differences',
#  'census block counts',
#  'the recently released 2021-04-28 vintage privacy-protected microdata files',
#  'ppmfs',
#  'the summaries',
#  'the accuracy',
#  'the new ppmfs',
#  'the census block level',
#  'the zip archive',
#  'three files',
#  'the race_by_age_differences.xlsx file',
#  'block-level discrepancies',
#  'five race/ethnicity categories',
#  'three age groups',
#  'the race/ethnicity categories',
#  'the age groups',
#  'the miscellaneous_differences.xlsx file summarizes block-level discrepancies',
#  'the following criteria',
#  'a pdf file',
#  'the excel spreadsheets',
#  'publications',
#  'research reports',
#  'a product-specific citation',
#  'this general form',
#  'david van riper',
#  'tracy kugler',
#  'jonathan schroeder',
#  'ipums nhgis privacy-protected 2010 census demonstration data',
#  'version yyyymmdd',
#  'database',
#  'minneapolis',
#  'yyyymmdd',
#  'the data vintage',
#  'the ppmf version',
#  'a complete recommended citation',
#  'the codebooks',
#  'our tabulation',
#  "the census bureau's privacy-protected microdata files",
#  'the construction',
#  'the privacy-protected demonstration data',
#  'funding',
#  'ses-1825768',
#  'the sloan foundation',
#  'g-2019',
#  'key resources',
#  'support',
#  'p2chd041023',
#  'the school attendance boundary information system',
#  'sabins',
#  'a national science foundation-funded project',
#  'school attendance areas',
#  'school catchment areas',
#  'selected areas',
#  'the 2009-10, 2010-11',
#  '2011-12 school years',
#  'the sabins project',
#  'no future data',
#  'the census',
#  'gis data',
#  'the foreseeable future',
#  "sabins' project information",
#  'supplemental datasets',
#  'a sabins-specific website',
#  'august xx',
#  'the underlying platform',
#  'the information',
#  'a joint project',
#  'the college',
#  'william',
#  'mary',
#  'principal investigators',
#  'john robert warren',
#  'saporito',
#  'access',
#  'those data',
#  'school information',
#  'the national center',
#  'education statistics',
#  '(nces) common core',
#  'the database design',
#  'the school attendance boundaries',
#  'access crosswalks',
#  'school attendance boundaries',
#  'schools',
#  'the nces',
#  'common core',
#  '2010 census blocks',
#  'other supplemental data',
#  'statistical',
#  'geographic data',
#  'the sources',
#  'the school attendance',
#  'boundary mapping files',
#  'demographic characteristics',
#  'the sabins',
#  'releases',
#  'summary tablestime series tablesgis filesgeographic crosswalks',
#  'all u.s. decennial censuses',
#  'the american community survey',
#  'a selection',
#  'other sources',
#  'the nhgis',
#  '\xa0data finder',
#  'which tables',
#  'geographic level',
#  'year',
#  'topic',
#  'source dataset',
#  'more details',
#  'the data finder',
#  'the\xa0environmental summaries',
#  'nhgis\xa0time series',
#  'a range',
#  'basic 100%-count statistics',
#  'the 1970-2010 censuses',
#  'several popular sample-based statistics',
#  'the 1970-2000 long-form surveys',
#  'the 2008-2012 5-year american community survey',
#  'a total population table',
#  'a persons',
#  'sex table',
#  'nominally integrated time series tables',
#  'names',
#  'codes',
#  'regard',
#  'boundary changes',
#  'up to 8 geographic levels',
#  'the nation',
#  'the set',
#  'covered levels',
#  'statistics',
#  'each level',
#  'each source year',
#  '.. geographically standardized time series tables',
#  'estimates',
#  "a single year's geographic units",
#  'other years',
#  '2010 100%-count statistics',
#  '2010 geographic units',
#  '10 geographic levels',
#  'groups',
#  'all topics',
#  'which time series',
#  'the topics filter window',
#  'the nhgis\xa0data finder',
#  'topics',
#  'the "ts" icon',
#  'all available time series tables',
#  'the table',
#  'the geographic units',
#  'nhgis shapefiles',
#  'the extent',
#  'coverage',
#  'only 8 cities',
#  'more detailed coverage information',
#  'the years',
#  'the survey years',
#  'the units',
#  'the vintages',
#  '2011 nhgis boundary files',
#  '2011 american community survey tabulations',
#  '2009 core based statistical areas',
#  '2000 public use microdata areas',
#  'the basis',
#  'all earlier nhgis boundaries',
#  'the 2000 tiger/line files',
#  "later years' boundaries",
#  'the tiger/line release',
#  'the same year',
#  'more information',
#  'gis file years',
#  'sources',
#  'a.',
#  '2000) tiger/line featuresb',
#  '2 versions',
#  '2010 tiger/line featuresc',
#  '3 versions',
#  '2010 tiger/line featuresd',
#  '2000 tiger/line features',
#  '2008 tiger/line featurese',
#  'not 2000) tiger/line featuresf',
#  '2012 boundaries',
#  'congressional districts',
#  'the special 113th congress tiger/line release',
#  'not 2012 tiger/line features)g',
#  'boundaries',
#  '2011-2012 school years',
#  '2010 tiger/line features',
#  'tabular data',
#  '2011 tiger/line source files.)i',
#  '4 versions',
#  '2010 tiger/line featuresj',
#  '2010 tiger/line featuresk',
#  '2012 basis',
#  '* census tract',
#  'block group boundaries',
#  'the 2009 tiger/line files',
#  'these boundaries',
#  '2009 acs tables',
#  'nhgis geographic crosswalk files',
#  "one year's data",
#  "another's geographic units",
#  'these years',
#  'the geographic crosswalks page',
#  'nhgis summary tables',
#  'the data source',
#  'survey coverage',
#  '100% count',
#  'the breakdown variables',
#  'nhgis datasets',
#  'turn',
#  'dataset groups',
#  'a single census program',
#  'specific data measurement',
#  'release years',
#  'group',
#  '5 datasets',
#  "the us census bureau's 2019 american community survey",
#  'one dataset',
#  'the 1-year summary file',
#  '2019 population',
#  'housing characteristics',
#  'a population',
#  'the 5-year summary file',
#  'average characteristics',
#  '4 datasets',
#  'a different set',
#  "the us census bureau's 2018 american community survey",
#  '2018 population',
#  "the us census bureau's 2017 american community survey",
#  '2017 population',
#  "the us census bureau's 2016 american community survey",
#  '2016 population',
#  "the us census bureau's 2015 american community survey",
#  '2015 population',
#  "the us census bureau's 2014 american community survey",
#  '2014 population',
#  '6 datasets',
#  "the us census bureau's 2013 american community survey",
#  '2013 population',
#  'the second dataset',
#  'the 3-year summary file',
#  "the us census bureau's 2012 american community survey",
#  '2012 population',
#  "the us census bureau's 2011 american community survey",
#  '2011 population',
#  'the period',
#  ...]

# %%
keyword = 'census'

for url, words in data.items():
    for word in words:
        if keyword in word:
            print(url)
            break
# Out:
# https://www.nhgis.org/
# https://www.nhgis.org/about
# https://www.nhgis.org/user-resources/geographic-crosswalks
# https://www.nhgis.org/user-resources/environmental-summaries
# https://www.nhgis.org/privacy-protected-demonstration-data
# https://www.nhgis.org/sabins
# https://www.nhgis.org/user-resources/data-availability
# https://www.nhgis.org/user-resources/datasets-overview
# https://www.nhgis.org/documentation/tabular-data
# https://www.nhgis.org/documentation/time-series
# https://www.nhgis.org/documentation/gis-data
# https://www.nhgis.org/documentation/release-log
# https://www.nhgis.org/support/faq
# https://www.nhgis.org/user-resources/users-guide
# https://www.nhgis.org/user-resources/project-description
# https://www.nhgis.org/news
# https://www.nhgis.org/nhgis-news
# https://www.nhgis.org/documentation/time-series/1990-blocks-to-2010-geog
# https://www.nhgis.org/documentation/time-series/2000-blocks-to-2010-geog
# https://www.nhgis.org/documentation/gis-data/place-points
# https://www.nhgis.org/mapping/mapping-options
# https://www.nhgis.org/project-information/release-log
# https://www.nhgis.org/differentially-private-2010-census-data
# https://www.nhgis.org/sabins-public-school-data
# https://www.nhgis.org/sabins-data-availability
# https://www.nhgis.org/sabins-gis-data-documentation
# https://www.nhgis.org/documentation/gis-data/point-files
# https://www.nhgis.org/documentation
